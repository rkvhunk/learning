# %%
solution_counts_dict = {'d5096d19-2115-4dd4-b82d-4c7026273ae0': 1}

# %%
tags_dict = {}

# %%
tag_data = {}

# %%
for tag in tag_data:
    tags_dict[str(tag[2])].get('child_tags', []).append({"child_tag_id": str(tag[0]), "child_tag_name": tag[1], "solution_count": solution_counts_dict.get(str(tag[0]), 0)})

# %%
tag={}
solution_counts_dict.get(str(tag), 0)
# Out:
# 0

# %%
import time

# %%
start = time.time()

# %%
end = time.time()-start

# %%
end
# Out:
# 1.437089443206787

# %%
a = [{"Front":{"SET1":[],"SET2":[{"attribute_type":"global","attribute_name":"Aadhar_Number","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":1},{"attribute_type":"global","attribute_name":"Name","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":2},{"attribute_type":"global","attribute_name":"DOB","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":3},{"attribute_type":"global","attribute_name":"Gender","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":4}]},"Back":{"SET1":[],"SET2":[{"attribute_type":"global","attribute_name":"Address_line1","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":1},{"attribute_type":"global","attribute_name":"Address_line2","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":2},{"attribute_type":"global","attribute_name":"Address_line3","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":3},{"attribute_type":"global","attribute_name":"Address_line4","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":4},{"attribute_type":"global","attribute_name":"Address_line5","logical_name":"","validations":[{"mandatory":"false","special_chars":"false","numeric_or_alphanumeric":"","no_multiple_values":"false","range_from":"","range_to":"","confidence_score":"90","most_accurate":"false"}],"dropdown_type":"","dropdown_values":[],"omr_config":{"single_or_multiple_omr":"","omr_options":[],"entity_extraction":""},"is_derived_attribute":"false","derived_formula":"","sentiment":"false","order_key":5}]}}]

# %%
a
# Out:
# [{'Front': {'SET1': [],
#    'SET2': [{'attribute_type': 'global',
#      'attribute_name': 'Aadhar_Number',
#      'logical_name': '',
#      'validations': [{'mandatory': 'false',
#        'special_chars': 'false',
#        'numeric_or_alphanumeric': '',
#        'no_multiple_values': 'false',
#        'range_from': '',
#        'range_to': '',
#        'confidence_score': '90',
#        'most_accurate': 'false'}],
#      'dropdown_type': '',
#      'dropdown_values': [],
#      'omr_config': {'single_or_multiple_omr': '',
#       'omr_options': [],
#       'entity_extraction': ''},
#      'is_derived_attribute': 'false',
#      'derived_formula': '',
#      'sentiment': 'false',
#      'order_key': 1},
#     {'attribute_type': 'global',
#      'attribute_name': 'Name',
#      'logical_name': '',
#      'validations': [{'mandatory': 'false',
#        'special_chars': 'false',
#        'numeric_or_alphanumeric': '',
#        'no_multiple_values': 'false',
#        'range_from': '',
# ...

# %%
a[0]
# Out:
# {'Front': {'SET1': [],
#   'SET2': [{'attribute_type': 'global',
#     'attribute_name': 'Aadhar_Number',
#     'logical_name': '',
#     'validations': [{'mandatory': 'false',
#       'special_chars': 'false',
#       'numeric_or_alphanumeric': '',
#       'no_multiple_values': 'false',
#       'range_from': '',
#       'range_to': '',
#       'confidence_score': '90',
#       'most_accurate': 'false'}],
#     'dropdown_type': '',
#     'dropdown_values': [],
#     'omr_config': {'single_or_multiple_omr': '',
#      'omr_options': [],
#      'entity_extraction': ''},
#     'is_derived_attribute': 'false',
#     'derived_formula': '',
#     'sentiment': 'false',
#     'order_key': 1},
#    {'attribute_type': 'global',
#     'attribute_name': 'Name',
#     'logical_name': '',
#     'validations': [{'mandatory': 'false',
#       'special_chars': 'false',
#       'numeric_or_alphanumeric': '',
#       'no_multiple_values': 'false',
#       'range_from': '',
#       'range_to': '',
# ...

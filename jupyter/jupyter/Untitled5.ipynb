# %%
json = {
  "solution_id": "${solution_id}",
  "entities": [
    {
      "entity_name": "Applicant_Description_of_Operations",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Additional_Named_Insured",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Payment_Plan",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Payment_Plan_Policy_Info",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Down_Payment_Percent",
      "type": "master"
    },
    {
      "entity_name": "Location_Tag",
      "type": "master"
    },
    {
      "entity_name": "Location_Update_Rating_Info",
      "type": "master"
    },
    {
      "entity_name": "Location_State",
      "type": "master"
    },
    {
      "entity_name": "Location_Class_Code",
      "type": "master"
    },
    {
      "entity_name": "Location_Description_Code",
      "type": "master"
    },
    {
      "entity_name": "Location_No_of_Full_time_emp",
      "type": "master"
    },
    {
      "entity_name": "Location_SIC",
      "type": "master"
    },
    {
      "entity_name": "Location_NAICS",
      "type": "master"
    },
    {
      "entity_name": "Location_Esti_Annual_Remuneration_Pyroll",
      "type": "master"
    },
    {
      "entity_name": "Location_Rate",
      "type": "master"
    },
    {
      "entity_name": "Location_Esti_Annual_Manual_Premium",
      "type": "master"
    },
    {
      "entity_name": "Policy_Info_Tot_Esti_Annual_Premium",
      "type": "master"
    },
    {
      "entity_name": "Policy_Info_States",
      "type": "master"
    },
    {
      "entity_name": "Policy_Info_Emloyers Liability",
      "type": "master"
    },
    {
      "entity_name": "Policy_info_Other_States_Insurance",
      "type": "master"
    },
    {
      "entity_name": "Policy_Other_Coverages_Tag",
      "type": "master"
    },
    {
      "entity_name": "Policy_Tot_Esti_Annual_Premium_all_States",
      "type": "master"
    },
    {
      "entity_name": "Policy_Tot_Minimum_Premium_all_States",
      "type": "master"
    },
    {
      "entity_name": "Policy_Total_Deposit_Premium_all_States",
      "type": "master"
    },
    {
      "entity_name": "Additional_Coverages_Tag",
      "type": "master"
    },
    {
      "entity_name": "Additional_Coverages_Code",
      "type": "master"
    },
    {
      "entity_name": "Additional_Coverages_Description",
      "type": "master"
    },
    {
      "entity_name": "Additional_Coverages_Limit1",
      "type": "master"
    },
    {
      "entity_name": "Additional_Coverages_Limit2",
      "type": "master"
    },
    {
      "entity_name": "Additional_Coverages_Limit3",
      "type": "master"
    },
    {
      "entity_name": "Individual_Name",
      "type": "master"
    },
    {
      "entity_name": "Individual_Title_Relationship",
      "type": "master"
    },
    {
      "entity_name": "Individual_Ownership_percent",
      "type": "master"
    },
    {
      "entity_name": "Individual_Duties",
      "type": "master"
    },
    {
      "entity_name": "Prior_Carrier_Tag",
      "type": "master"
    },
    {
      "entity_name": "Prior_Carrier_Year",
      "type": "master"
    },
    {
      "entity_name": "Prior_Carrier_Name",
      "type": "master"
    },
    {
      "entity_name": "Prior_Carrier_Policy_Number",
      "type": "master"
    },
    {
      "entity_name": "Prior_Carrier_Annual_Premium",
      "type": "master"
    },
    {
      "entity_name": "Prior_Carrier_Experience_Modification",
      "type": "master"
    },
    {
      "entity_name": "Forms_and_Endorsement_Tag",
      "type": "master"
    },
    {
      "entity_name": "Forms_and_Endorsement_Number",
      "type": "master"
    },
    {
      "entity_name": "Forms_and_Endorsement_Name",
      "type": "master"
    },
    {
      "entity_name": "Forms_and_Endorsement_Edition_Date",
      "type": "master"
    },
    {
      "entity_name": "Remarks_Tag",
      "type": "master"
    },
    {
      "entity_name": "Remarks_Print_On_Form",
      "type": "master"
    },
    {
      "entity_name": "Remarks_Description",
      "type": "master"
    },
    {
      "entity_name": "Remarks_Detail",
      "type": "master"
    },
    {
      "entity_name": "Policy_Effective_Date",
      "type": "master"
    },
    {
      "entity_name": "Policy_Info_Emloyers_Liability",
      "type": "master"
    },
    {
      "entity_name": "Policy_Info_Each_accident",
      "type": "master"
    },
    {
      "entity_name": "Policy_Info_Disease_each_employee",
      "type": "master"
    },
    {
      "entity_name": "Location_Categories_duties_clasification_line1",
      "type": "master"
    },
    {
      "entity_name": "Policy_Info_Disease_policy_limit",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Calculation_Tag",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Calculation_total",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Increased_Limits_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Increased_Limits_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Deductible_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Deductible_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Exp_or_Modifi_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Exp_or_Modifi_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Assigned_Risk_Surcharge",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_ARAP_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_ARAP_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Schedule_Rating_Modifi_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Schedule_Rating_Modifi_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_CCPAP_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_CCPAP_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Standard_Premium_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Standard_Premium_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Premium_Discount_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Premium_Discount_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Expense_Constant_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Expense_Constant_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Taxes_Assessments_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Taxes_Assessments_amount",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Blank_field_line1",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Blank_field_rate",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Blank_filed_amount",
      "type": "master"
    },
    {
      "entity_name": "Policy_info_States_Insurance",
      "type": "master"
    },
    {
      "entity_name": "Location_No_of_part_time_emp",
      "type": "master"
    },
    {
      "entity_name": "Location_Address_line3",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Mailing_Address_line1",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Mailing_Address_line2",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Mailing_Address_line3",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Mailing_Address_line4",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Taxes_Assessments_field",
      "type": "master"
    },
    {
      "entity_name": "Location_Address_line1",
      "type": "master"
    },
    {
      "entity_name": "Location_Address_line2",
      "type": "master"
    },
    {
      "entity_name": "Line_Status",
      "type": "master"
    },
    {
      "entity_name": "Location_Address_line4",
      "type": "master"
    },
    {
      "entity_name": "Line_Commision_percent",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Calculation_Premium_State",
      "type": "master"
    },
    {
      "entity_name": "Tot_Premium_Blank_field_line2",
      "type": "master"
    },
    {
      "entity_name": "Location_Categories_duties_clasification_line2",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Info_Audit",
      "type": "master"
    },
    {
      "entity_name": "Policy_Description",
      "type": "master"
    },
    {
      "entity_name": "Policy_Number",
      "type": "master"
    },
    {
      "entity_name": "Policy_Estimated Premium",
      "type": "master"
    },
    {
      "entity_name": "Policy_Commission",
      "type": "master"
    },
    {
      "entity_name": "Line_Billing_Type",
      "type": "master"
    },
    {
      "entity_name": "Line_Issuing_Company",
      "type": "master"
    },
    {
      "entity_name": "Line_Estimated Premium",
      "type": "master"
    },
    {
      "entity_name": "Billing_Address",
      "type": "master"
    },
    {
      "entity_name": "Pr_Br_Commissions",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Info",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Name",
      "type": "master"
    },
    {
      "entity_name": "Applicant_FEIN",
      "type": "master"
    },
    {
      "entity_name": "Applicant_NCCI_ID",
      "type": "master"
    },
    {
      "entity_name": "Applicant_SIC",
      "type": "master"
    },
    {
      "entity_name": "Applicant_NAICS",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Business_Type",
      "type": "master"
    },
    {
      "entity_name": "Applicant_ID_Number",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Year_of_Business",
      "type": "master"
    },
    {
      "entity_name": "Applicant_Other_Rating_Bureau",
      "type": "master"
    },
    {
      "entity_name": "Apllicant_Nature_of_Business",
      "type": "master"
    }
  ]
}

# %%
json['solution_id']
# Out:
# '${solution_id}'

# %%
data = {
	"solution_id": "6667c1e3-7f8f-464b-b99a-d33925f9bb65",
	"entities": [{
		"entity_name": "Applicant_Description_of_Operations",
		"type": "master"
	}, {
		"entity_name": "Applicant_Additional_Named_Insured",
		"type": "master"
	}, {
		"entity_name": "Applicant_Payment_Plan",
		"type": "master"
	}, {
		"entity_name": "Applicant_Payment_Plan_Policy_Info",
		"type": "master"
	}, {
		"entity_name": "Applicant_Down_Payment_Percent",
		"type": "master"
	}, {
		"entity_name": "Location_Tag",
		"type": "master"
	}, {
		"entity_name": "Location_Update_Rating_Info",
		"type": "master"
	}, {
		"entity_name": "Location_State",
		"type": "master"
	}, {
		"entity_name": "Location_Class_Code",
		"type": "master"
	}, {
		"entity_name": "Location_Description_Code",
		"type": "master"
	}, {
		"entity_name": "Location_No_of_Full_time_emp",
		"type": "master"
	}, {
		"entity_name": "Location_SIC",
		"type": "master"
	}, {
		"entity_name": "Location_NAICS",
		"type": "master"
	}, {
		"entity_name": "Location_Esti_Annual_Remuneration_Pyroll",
		"type": "master"
	}, {
		"entity_name": "Location_Rate",
		"type": "master"
	}, {
		"entity_name": "Location_Esti_Annual_Manual_Premium",
		"type": "master"
	}, {
		"entity_name": "Policy_Info_Tot_Esti_Annual_Premium",
		"type": "master"
	}, {
		"entity_name": "Policy_Info_States",
		"type": "master"
	}, {
		"entity_name": "Policy_Info_Emloyers Liability",
		"type": "master"
	}, {
		"entity_name": "Policy_info_Other_States_Insurance",
		"type": "master"
	}, {
		"entity_name": "Policy_Other_Coverages_Tag",
		"type": "master"
	}, {
		"entity_name": "Policy_Tot_Esti_Annual_Premium_all_States",
		"type": "master"
	}, {
		"entity_name": "Policy_Tot_Minimum_Premium_all_States",
		"type": "master"
	}, {
		"entity_name": "Policy_Total_Deposit_Premium_all_States",
		"type": "master"
	}, {
		"entity_name": "Additional_Coverages_Tag",
		"type": "master"
	}, {
		"entity_name": "Additional_Coverages_Code",
		"type": "master"
	}, {
		"entity_name": "Additional_Coverages_Description",
		"type": "master"
	}, {
		"entity_name": "Additional_Coverages_Limit1",
		"type": "master"
	}, {
		"entity_name": "Additional_Coverages_Limit2",
		"type": "master"
	}, {
		"entity_name": "Additional_Coverages_Limit3",
		"type": "master"
	}, {
		"entity_name": "Individual_Name",
		"type": "master"
	}, {
		"entity_name": "Individual_Title_Relationship",
		"type": "master"
	}, {
		"entity_name": "Individual_Ownership_percent",
		"type": "master"
	}, {
		"entity_name": "Individual_Duties",
		"type": "master"
	}, {
		"entity_name": "Prior_Carrier_Tag",
		"type": "master"
	}, {
		"entity_name": "Prior_Carrier_Year",
		"type": "master"
	}, {
		"entity_name": "Prior_Carrier_Name",
		"type": "master"
	}, {
		"entity_name": "Prior_Carrier_Policy_Number",
		"type": "master"
	}, {
		"entity_name": "Prior_Carrier_Annual_Premium",
		"type": "master"
	}, {
		"entity_name": "Prior_Carrier_Experience_Modification",
		"type": "master"
	}, {
		"entity_name": "Forms_and_Endorsement_Tag",
		"type": "master"
	}, {
		"entity_name": "Forms_and_Endorsement_Number",
		"type": "master"
	}, {
		"entity_name": "Forms_and_Endorsement_Name",
		"type": "master"
	}, {
		"entity_name": "Forms_and_Endorsement_Edition_Date",
		"type": "master"
	}, {
		"entity_name": "Remarks_Tag",
		"type": "master"
	}, {
		"entity_name": "Remarks_Print_On_Form",
		"type": "master"
	}, {
		"entity_name": "Remarks_Description",
		"type": "master"
	}, {
		"entity_name": "Remarks_Detail",
		"type": "master"
	}, {
		"entity_name": "Policy_Effective_Date",
		"type": "master"
	}, {
		"entity_name": "Policy_Info_Emloyers_Liability",
		"type": "master"
	}, {
		"entity_name": "Policy_Info_Each_accident",
		"type": "master"
	}, {
		"entity_name": "Policy_Info_Disease_each_employee",
		"type": "master"
	}, {
		"entity_name": "Location_Categories_duties_clasification_line1",
		"type": "master"
	}, {
		"entity_name": "Policy_Info_Disease_policy_limit",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Calculation_Tag",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Calculation_total",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Increased_Limits_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Increased_Limits_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Deductible_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Deductible_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Exp_or_Modifi_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Exp_or_Modifi_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Assigned_Risk_Surcharge",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_ARAP_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_ARAP_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Schedule_Rating_Modifi_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Schedule_Rating_Modifi_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_CCPAP_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_CCPAP_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Standard_Premium_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Standard_Premium_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Premium_Discount_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Premium_Discount_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Expense_Constant_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Expense_Constant_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Taxes_Assessments_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Taxes_Assessments_amount",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Blank_field_line1",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Blank_field_rate",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Blank_filed_amount",
		"type": "master"
	}, {
		"entity_name": "Policy_info_States_Insurance",
		"type": "master"
	}, {
		"entity_name": "Location_No_of_part_time_emp",
		"type": "master"
	}, {
		"entity_name": "Location_Address_line3",
		"type": "master"
	}, {
		"entity_name": "Applicant_Mailing_Address_line1",
		"type": "master"
	}, {
		"entity_name": "Applicant_Mailing_Address_line2",
		"type": "master"
	}, {
		"entity_name": "Applicant_Mailing_Address_line3",
		"type": "master"
	}, {
		"entity_name": "Applicant_Mailing_Address_line4",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Taxes_Assessments_field",
		"type": "master"
	}, {
		"entity_name": "Location_Address_line1",
		"type": "master"
	}, {
		"entity_name": "Location_Address_line2",
		"type": "master"
	}, {
		"entity_name": "Line_Status",
		"type": "master"
	}, {
		"entity_name": "Location_Address_line4",
		"type": "master"
	}, {
		"entity_name": "Line_Commision_percent",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Calculation_Premium_State",
		"type": "master"
	}, {
		"entity_name": "Tot_Premium_Blank_field_line2",
		"type": "master"
	}, {
		"entity_name": "Location_Categories_duties_clasification_line2",
		"type": "master"
	}, {
		"entity_name": "Applicant_Info_Audit",
		"type": "master"
	}, {
		"entity_name": "Policy_Description",
		"type": "master"
	}, {
		"entity_name": "Policy_Number",
		"type": "master"
	}, {
		"entity_name": "Policy_Estimated Premium",
		"type": "master"
	}, {
		"entity_name": "Policy_Commission",
		"type": "master"
	}, {
		"entity_name": "Line_Billing_Type",
		"type": "master"
	}, {
		"entity_name": "Line_Issuing_Company",
		"type": "master"
	}, {
		"entity_name": "Line_Estimated Premium",
		"type": "master"
	}, {
		"entity_name": "Billing_Address",
		"type": "master"
	}, {
		"entity_name": "Pr_Br_Commissions",
		"type": "master"
	}, {
		"entity_name": "Applicant_Info",
		"type": "master"
	}, {
		"entity_name": "Applicant_Name",
		"type": "master"
	}, {
		"entity_name": "Applicant_FEIN",
		"type": "master"
	}, {
		"entity_name": "Applicant_NCCI_ID",
		"type": "master"
	}, {
		"entity_name": "Applicant_SIC",
		"type": "master"
	}, {
		"entity_name": "Applicant_NAICS",
		"type": "master"
	}, {
		"entity_name": "Applicant_Business_Type",
		"type": "master"
	}, {
		"entity_name": "Applicant_ID_Number",
		"type": "master"
	}, {
		"entity_name": "Applicant_Year_of_Business",
		"type": "master"
	}, {
		"entity_name": "Applicant_Other_Rating_Bureau",
		"type": "master"
	}, {
		"entity_name": "Apllicant_Nature_of_Business",
		"type": "master"
	}]
}

# %%
data
# Out:
# {'solution_id': '6667c1e3-7f8f-464b-b99a-d33925f9bb65',
#  'entities': [{'entity_name': 'Applicant_Description_of_Operations',
#    'type': 'master'},
#   {'entity_name': 'Applicant_Additional_Named_Insured', 'type': 'master'},
#   {'entity_name': 'Applicant_Payment_Plan', 'type': 'master'},
#   {'entity_name': 'Applicant_Payment_Plan_Policy_Info', 'type': 'master'},
#   {'entity_name': 'Applicant_Down_Payment_Percent', 'type': 'master'},
#   {'entity_name': 'Location_Tag', 'type': 'master'},
#   {'entity_name': 'Location_Update_Rating_Info', 'type': 'master'},
#   {'entity_name': 'Location_State', 'type': 'master'},
#   {'entity_name': 'Location_Class_Code', 'type': 'master'},
#   {'entity_name': 'Location_Description_Code', 'type': 'master'},
#   {'entity_name': 'Location_No_of_Full_time_emp', 'type': 'master'},
#   {'entity_name': 'Location_SIC', 'type': 'master'},
#   {'entity_name': 'Location_NAICS', 'type': 'master'},
# ...

# %%
data['solution_id']
# Out:
# '6667c1e3-7f8f-464b-b99a-d33925f9bb65'
